# %% [markdown]
# ### Google BLEU scores

# %%
import pandas as pd
import numpy as np
import string
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %%
N = 4
group1 = (0.52, 0.44, 0.37, 0.32)
group2 = (0.41, 0.41, 0.37, 0.32)
#group3 = (0.42, 0.41, 0.37, 0.33)
g1_std = (0.11, 0.03, 0.02, 0.01)
# g2_std = (0.11, 0.03, 0, 0)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, group1, width, yerr=g1_std)
p2 = plt.bar(ind, group2, width,
             bottom=group1, yerr = g1_std)
#p3 = plt.bar(ind, group3, width)

plt.ylabel('Scores')
plt.title('BLUE scores by groups of data')
plt.xticks(ind, ('1-gram', '2-gram', '3-gram', '4-gram'))
plt.yticks(np.arange(0, 1, 0.1))
plt.legend((p1[0], p2[0]), ('Group1', 'Group2'))

plt.show()
